# %%
import torch
from conv import MNISTNetwork
from trainer import Trainer
from dataloader import retrieve_mnist

# %%
USE_CUDA = torch.cuda.is_available()
print(USE_CUDA)

device = torch.device('cuda:0' if USE_CUDA else 'cpu')
print('학습을 진행하는 기기:',device)
# Out:
# True
# 학습을 진행하는 기기: cuda:0

# %%
batch_size = 128
epoch = 10
n_iter = 100
trainer = Trainer(MNISTNetwork, epoch=epoch, n_iter=n_iter, device=device)

# %%
data = retrieve_mnist(batch_size=batch_size)
trainer.train(data)
# Out:
# 0.9999
# tensor([[0.9995, 0.9987, 0.9961,  ..., 0.9985, 0.9993, 0.9969],
#         [0.9987, 0.9996, 0.9972,  ..., 0.9993, 0.9993, 0.9982],
#         [0.9961, 0.9972, 0.9998,  ..., 0.9971, 0.9975, 0.9964],
#         ...,
#         [0.9985, 0.9993, 0.9971,  ..., 0.9999, 0.9989, 0.9971],
#         [0.9993, 0.9993, 0.9975,  ..., 0.9989, 0.9999, 0.9979],
#         [0.9969, 0.9982, 0.9964,  ..., 0.9971, 0.9979, 1.0000]],
#        device='cuda:0', grad_fn=<MmBackward0>)
# Epoch: 0, Iteration:100, loss: 15936.8193359375
# ACC: 0.0, NMI: 0.014746626590667892, ARI: -0.00036369273001772014
# tensor([[1.0000, 0.9993, 0.9986,  ..., 0.9996, 0.9989, 0.9984],
#         [0.9993, 0.9998, 0.9993,  ..., 0.9990, 0.9995, 0.9972],
#         [0.9986, 0.9993, 0.9996,  ..., 0.9984, 0.9989, 0.9963],
#         ...,
#         [0.9996, 0.9990, 0.9984,  ..., 0.9998, 0.9988, 0.9993],
#         [0.9989, 0.9995, 0.9989,  ..., 0.9988, 1.0001, 0.9971],
#         [0.9984, 0.9972, 0.9963,  ..., 0.9993, 0.9971, 1.0003]],
#        device='cuda:0', grad_fn=<MmBackward0>)
# Epoch: 1, Iteration:100, loss: 16005.44921875
# ACC: 0.0, NMI: 0.016710751918756143, ARI: 0.00022433538566266113
# tensor([[0.9999, 0.9920, 0.9982,  ..., 0.9946, 0.9942, 0.9971],
#         [0.9920, 0.9999, 0.9945,  ..., 0.9920, 0.9972, 0.9931],
#         [0.9982, 0.9945, 1.0001,  ..., 0.9964, 0.9954, 0.9986],
#         ...,
#         [0.9946, 0.9920, 0.9964,  ..., 1.0002, 0.9972, 0.9949],
#         [0.9942, 0.9972, 0.9954,  ..., 0.9972, 0.9998, 0.9945],
#         [0.9971, 0.9931, 0.9986,  ..., 0.9949, 0.9945, 0.9999]],
#        device='cuda:0', grad_fn=<MmBackward0>)
# Epoch: 2, Iteration:100, loss: 15919.30078125
# ACC: 0.0, NMI: 0.01588200799467867, ARI: 7.144464959815614e-05
# tensor([[1.0001, 0.9928, 0.9890,  ..., 0.9984, 0.9998, 0.9908],
#         [0.9928, 1.0002, 0.9901,  ..., 0.9971, 0.9923, 0.9922],
#         [0.9890, 0.9901, 0.9996,  ..., 0.9940, 0.9890, 0.9946],
#         ...,
#         [0.9984, 0.9971, 0.9940,  ..., 1.0004, 0.9982, 0.9962],
#         [0.9998, 0.9923, 0.9890,  ..., 0.9982, 0.9996, 0.9911],
#         [0.9908, 0.9922, 0.9946,  ..., 0.9962, 0.9911, 0.9999]],
#        device='cuda:0', grad_fn=<MmBackward0>)
# Epoch: 3, Iteration:100, loss: 15837.0625
# ACC: 0.0, NMI: 0.0016336983476073598, ARI: -3.333895135113016e-05
# tensor([[0.9998, 0.9860, 0.9929,  ..., 0.9744, 0.9994, 0.9984],
#         [0.9860, 1.0002, 0.9752,  ..., 0.9576, 0.9873, 0.9912],
#         [0.9929, 0.9752, 1.0000,  ..., 0.9638, 0.9908, 0.9895],
#         ...,
#         [0.9744, 0.9576, 0.9638,  ..., 1.0001, 0.9743, 0.9730],
#         [0.9994, 0.9873, 0.9908,  ..., 0.9743, 0.9998, 0.9989],
#         [0.9984, 0.9912, 0.9895,  ..., 0.9730, 0.9989, 0.9996]],
#        device='cuda:0', grad_fn=<MmBackward0>)
# Epoch: 4, Iteration:100, loss: 15853.087890625
# ACC: 0.0, NMI: 0.03191824309899766, ARI: 0.00043916100651811215
# tensor([[0.9996, 0.9849, 0.9868,  ..., 0.9884, 0.9884, 0.9723],
#         [0.9849, 1.0000, 0.9675,  ..., 0.9994, 0.9707, 0.9526],
#         [0.9868, 0.9675, 1.0001,  ..., 0.9708, 0.9918, 0.9567],
#         ...,
#         [0.9884, 0.9994, 0.9708,  ..., 1.0000, 0.9748, 0.9559],
#         [0.9884, 0.9707, 0.9918,  ..., 0.9748, 0.9998, 0.9586],
#         [0.9723, 0.9526, 0.9567,  ..., 0.9559, 0.9586, 0.9994]],
#        device='cuda:0', grad_fn=<MmBackward0>)
# Epoch: 5, Iteration:100, loss: 15747.505859375
# ACC: 7.735148514851485e-05, NMI: 0.05472918787391206, ARI: 0.0025135011835140516
# tensor([[1.0001, 0.9907, 0.9973,  ..., 0.9969, 0.9739, 0.9980],
#         [0.9907, 0.9999, 0.9897,  ..., 0.9978, 0.9649, 0.9861],
#         [0.9973, 0.9897, 1.0002,  ..., 0.9945, 0.9737, 0.9928],
#         ...,
#         [0.9969, 0.9978, 0.9945,  ..., 1.0003, 0.9716, 0.9938],
#         [0.9739, 0.9649, 0.9737,  ..., 0.9716, 0.9997, 0.9673],
#         [0.9980, 0.9861, 0.9928,  ..., 0.9938, 0.9673, 0.9998]],
#        device='cuda:0', grad_fn=<MmBackward0>)
# Epoch: 6, Iteration:100, loss: 15712.83203125
# ACC: 0.0796720297029703, NMI: 0.09663746973547795, ARI: 0.0397932981523164
# tensor([[0.9997, 0.9707, 0.9260,  ..., 0.9622, 0.9902, 0.9728],
#         [0.9707, 1.0002, 0.9734,  ..., 0.9881, 0.9797, 0.9841],
#         [0.9260, 0.9734, 0.9998,  ..., 0.9412, 0.9344, 0.9397],
#         ...,
#         [0.9622, 0.9881, 0.9412,  ..., 1.0001, 0.9711, 0.9758],
#         [0.9902, 0.9797, 0.9344,  ..., 0.9711, 1.0004, 0.9949],
#         [0.9728, 0.9841, 0.9397,  ..., 0.9758, 0.9949, 1.0000]],
#        device='cuda:0', grad_fn=<MmBackward0>)
# Epoch: 7, Iteration:100, loss: 15531.6171875
# ACC: 0.04385829207920792, NMI: 0.1276053363726062, ARI: 0.07223387701805459
# tensor([[1.0005, 0.9505, 0.9404,  ..., 0.9127, 0.9509, 0.9445],
#         [0.9505, 0.9997, 0.9860,  ..., 0.9595, 0.9964, 0.9914],
#         [0.9404, 0.9860, 1.0001,  ..., 0.9912, 0.9895, 0.9848],
#         ...,
#         [0.9127, 0.9595, 0.9912,  ..., 0.9998, 0.9627, 0.9587],
#         [0.9509, 0.9964, 0.9895,  ..., 0.9627, 0.9999, 0.9930],
#         [0.9445, 0.9914, 0.9848,  ..., 0.9587, 0.9930, 1.0000]],
#        device='cuda:0', grad_fn=<MmBackward0>)
# Epoch: 8, Iteration:100, loss: 15475.291015625
# ACC: 0.001082920792079208, NMI: 0.11202071883681862, ARI: 0.0540092731596922
# tensor([[1.0000, 0.9927, 0.9900,  ..., 0.9971, 0.9939, 0.9939],
#         [0.9927, 1.0002, 0.9984,  ..., 0.9848, 0.9793, 0.9987],
#         [0.9900, 0.9984, 1.0002,  ..., 0.9820, 0.9768, 0.9963],
#         ...,
#         [0.9971, 0.9848, 0.9820,  ..., 1.0001, 0.9975, 0.9864],
#         [0.9939, 0.9793, 0.9768,  ..., 0.9975, 1.0001, 0.9806],
#         [0.9939, 0.9987, 0.9963,  ..., 0.9864, 0.9806, 0.9998]],
#        device='cuda:0', grad_fn=<MmBackward0>)
# Epoch: 9, Iteration:100, loss: 15298.5615234375
# ACC: 0.03674195544554455, NMI: 0.1396629482071, ARI: 0.08025927218006146
